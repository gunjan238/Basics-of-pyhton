# %%
def f2():
    x = "Gunjan"
    print(x)
f2()
# Out:
# Gunjan

# %%
def f1():
    global y
    x = "Python"
    y = "ML"
    z = "AI" 
    print(y)
    print(z)
f1()
# Out:
# ML
# AI

# %%
z = 23
print(z)
# Out:
# 23

# %%
x = 1
print(x)
print(type(x))
complex(x)
# Out:
# 1
# <class 'int'>
# (1+0j)

# %%
float(1j)
int(2j)
#Can't convert complex to float as well as int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-1a8fb8aa562e> in <module>
# ----> 1 float(1j)
#       2 int(2j)
#
# TypeError: can't convert complex to float

# %%
#we can add strings but cannot add str and int, to add int need to treat int as str
"sad" + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-1fe519694727> in <module>
#       1 #we can add strings but cannot add str and int, to add int need to treat int as str
# ----> 2 "sad" + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
"sad"+"2"
# Out:
# 'sad2'

# %%
Name = "Gunjan"
Surname = "Kothari"
print(Name + " " +Surname)
# Out:
# Gunjan Kothari

# %%
a = 2.3
#Convert to int
int(a)
# Out:
# 2

# %%
b = 312
#Convert to float
float(b)
# Out:
# 312.0

# %%
c = 3j
#Convert to int
int(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-7f6c077ebe3c> in <module>
#       1 c = 3j
#       2 #Convert to int
# ----> 3 int(c)
#
# TypeError: can't convert complex to int

# %%
complex(a,b)
# Out:
# (2.3+312j)

# %%
age = 21
txt = "My name is Gunjan, and I am {}"
print(txt.format(age))
# Out:
# My name is Gunjan, and I am 21

# %%
quantity = 3
item = "Bread"
price = 5
myorder = "I want {} piece of {} for {} rupees."
print(myorder.format(quantity,item,price))
# Out:
# I want 3 piece of Bread for 5 rupees.

# %%
quantity = 3
item = "Bread"
price = 5
myorder = "I want {2} piece of {0} for {1} rupees."
print(myorder.format(item,price,quantity))
# Out:
# I want 3 piece of Bread for 5 rupees.

# %%
Name = input()
Age = input()
Class = "Ty"
College = "SP"
"My name is {} and I'm {} years old, study in {} class at {} college".format(Name,Age,Class,College)
# Out:
# Gunjan
# 21
# "My name is Gunjan and I'm 21 years old, study in Ty class at SP college"
