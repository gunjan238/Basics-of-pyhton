# %% [markdown]
# Name: Gunjan Atul Kothari
#
# Roll: 9145
#
#                              ASSIGNMENT 3
#
# Q33-40

# %%
import numpy as np
import math
import matplotlib.pyplot as plot
import pandas as pd

# %%
##solutionQ33) simple bar diagram 

data = { "Year":[2015,2016,2017,2018,2019],
        "Annual_Sales" : [12.5,13.4,7.5,20.1,16.1]
}

#Dataframe
data_frame = pd.DataFrame(data = data)
print(data_frame)

#Simple bar diagram
data_frame.plot.bar(x = "Year", y = "Annual_Sales", title = "Annual Sales per year")
plot.show(block=True)
# Out:
#    Year  Annual_Sales
# 0  2015          12.5
# 1  2016          13.4
# 2  2017           7.5
# 3  2018          20.1
# 4  2019          16.1

# %%
##Solution Q34) spike plot
data1 = { "X":[1,4,5,7,9],
        "f":[8,12,13,5,8]
}

#Dataframe
data_frame1 = pd.DataFrame(data = data1)
print(data_frame1)
data_frame1.plot.bar()
# Out:
#    X   f
# 0  1   8
# 1  4  12
# 2  5  13
# 3  7   5
# 4  9   8

# %%
##solution Q35) Generate 100 random numbers from B(20, 0.3) distribution and draw the boxplot.
Binomial=np.random.binomial(20,0.3,100)
Binomial
plot.boxplot(Binomial)
plot.title("Box plot of Random Numbers generated by Binomial Distribution")
# Out:
# Text(0.5, 1.0, 'Box plot of Random Numbers generated by Binomial Distribution')

# %%
##Q36) Generate 100 random numbers from N(0,1) distribution and draw the histogram.

x = np.random.normal(loc = 0, scale = 1,size = 100)
print(x)

plot.hist(x)
plot.title("Histogram")
# Out:
# [ 3.08592093e-01 -3.62836602e-01  1.71282254e-01 -1.51421643e+00
#  -8.58792993e-01  1.39257123e-01  4.35531704e-01 -5.92529692e-01
#  -1.14553580e+00 -2.47376604e-03  3.37300534e-02 -1.16996944e-01
#  -2.27827615e-01 -1.70938079e+00 -5.94108772e-01 -1.99885261e-01
#   1.42063193e-01 -9.75341978e-01  3.80895198e-01 -7.81213953e-01
#   5.93805503e-01  5.26221693e-01  5.77989991e-01 -1.01172093e+00
#   1.68783917e+00  8.71570191e-01 -3.12763356e-01  1.09030006e+00
#   8.08132240e-03  1.16044953e+00  1.06717529e+00  6.19841941e-01
#   2.65717146e+00 -4.19117898e-01  7.21739618e-01  2.98418908e-01
#  -1.16094171e+00 -9.82830774e-01 -1.66244689e-01 -2.95327769e-01
#   6.25172231e-01 -2.19867051e+00  4.52595665e-01  1.79348663e+00
#  -5.69659646e-02 -1.12992670e-01 -1.35554062e+00 -1.59913838e+00
#   4.56085806e-01  4.60899253e-01 -6.20893510e-01  1.25661508e+00
#   5.26235681e-01 -4.24548706e-01 -1.34141000e+00  2.78841822e+00
#  -8.64109582e-01  1.06664986e+00 -5.67824982e-03 -8.12651649e-01
#  -3.20326287e-01  5.81761458e-01 -4.08259538e-02 -4.81940197e-01
#   1.05925250e+00  2.38176687e-01 -7.34945235e-01 -1.61781001e+00
#  -1.29433111e+00 -5.48904843e-01 -2.97001625e-01  8.37042130e-01
#   4.37014250e-01  7.40797528e-01  7.15029793e-01  4.82364124e-01
#  -1.02032707e+00  1.05714120e+00  1.24724024e+00 -1.34063955e+00
#  -1.67116598e-01  1.56505729e+00 -7.95078093e-01  1.45236170e+00
#  -8.61457891e-01  1.52068479e-01  2.45819832e+00  3.68697961e-01
#  -3.72180785e-01  1.47782642e+00  6.15021013e-02  5.90872080e-01
#  -5.97035123e-01  1.19632093e+00 -6.09603538e-01  6.75107577e-01
#  -1.97073067e+00 -2.18389764e+00  1.05109004e-01  5.25693045e-01]
# Text(0.5, 1.0, 'Histogram')

# %%
##Q37)
X=(float)(input("value of X:"))
n=(int)(input("value of n: "))
sum1=1
for i in range(2,n+1):
    sum1=sum1+X**i
print("Evaluated Series is ",sum1)
# Out:
# value of X:0.5
# value of n: 2
# Evaluated Series is  1.25

# %%
##Q38) 

a=(int)(input("1st side of triangle: "))
b=(int)(input("2nd side of triangle: "))
c=(int)(input("3rd side of triangle: "))
# Semi parameter
s=(a+b+c)/2
#Area 
A=math.sqrt(s*(s-a)*(s-b)*(s-c))
A
# Out:
# 1st side of triangle: 4
# 2nd side of triangle: 8
# 3rd side of triangle: 9
# 15.998046755776157

# %%
##Q39)
X=2
n=5
mult=1
for i in range(2,n):
    mult=X**i
print(mult)
# Out:
# 16

# %%
##Q40)
r=(float)(input("Enter Radius: "))
a=3.14*r*r
c=2*3.14*r
print("Area of Circle is: ",a)
print("Circumference of Circle is: ",c)
# Out:
# Enter Radius: 5
# Area of Circle is:  78.5
# Circumference of Circle is:  31.400000000000002
