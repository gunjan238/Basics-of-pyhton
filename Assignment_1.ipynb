# %% [markdown]
# Assignment 01
#
# Name - Gunjan Kothari
#
# Roll no.: 9145

# %% [markdown]
# Lists
#
# A list is a collection which is ordered and changeable. In Python lists are written in squared brackets

# %%
# Create 2 listes
# A is list of Name and basic details
A = ['Gunjan','20','Khopoli']
# List of college details
B = ['T.Y.BSc','Statistics','9145','Tilak Road']

# %% [markdown]
# Performing various methods

# %%
# 1)  append() - Adds an element at th end of the list
print(A)
A.append("Male")
print(A)
# Out:
# ['Gunjan', '20', 'Khopoli']
# ['Gunjan', '20', 'Khopoli', 'Male']

# %%
# 2) copy() : Copies all the elements from the list
A1 = A.copy()
print(A)
# Out:
# ['Gunjan', '20', 'Khopoli', 'Male']

# %%
# 3) clear() : Removes all the elements from the list
A1.clear()
print(A1)
# Out:
# []

# %%
# 4) count() : Returns the number of elements with the specified value
A.append('20')
print(A)
x = A.count('20')
print(x)
# Out:
# ['Gunjan', '20', 'Khopoli', 'Male', '20']
# 2

# %%
# 5) del : Delete list
print(A1)
del A1
print(A1)
# Out:
# []
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b582ea2ff16a> in <module>
#       2 print(A1)
#       3 del A1
# ----> 4 print(A1)
#
# NameError: name 'A1' is not defined

# %%
# 6) extend() : Add the elements of the list (or any iterable), to the end of the current list
A.extend(B)
print(A)
# Out:
# ['Gunjan', '20', 'Khopoli', 'Male', '20', 'T.Y.BSc', 'Statistics', '9145', 'Tilak Road']

# %%
# 7) insert() : Adds an elemnt at the specified position
A.insert(2,'15 Km')
print(A)
# Out:
# ['Gunjan', '20', '15 Km', 'Khopoli', 'Male', '20', 'T.Y.BSc', 'Statistics', '9145', 'Tilak Road']

# %%
# 8) len() : Length of list
print(len(A))
# Out:
# 10

# %%
# 9) list() : Create list from inputs
C = list(('A','B','C'))
print(C)
# Out:
# ['A', 'B', 'C']

# %%
# 10) pop() : Removes the element at the specified position'
A.pop(2)
print(A)
# Out:
# ['Gunjan', '20', 'Khopoli', 'Male', '20', 'T.Y.BSc', 'Statistics', '9145', 'Tilak Road']

# %%
# 11) remove() : Removes the item with the specified value
A.remove('20')
print(A)
# Removes the 1st same element it matches
# Out:
# ['Gunjan', 'Khopoli', 'Male', '20', 'T.Y.BSc', 'Statistics', '9145', 'Tilak Road']

# %%
# 12) reverse() : Reverses the order of the list
A.reverse()
print(A)
# Out:
# ['Tilak Road', '9145', 'Statistics', 'T.Y.BSc', '20', 'Male', 'Khopoli', 'Gunjan']

# %%
# 13) sort() : Sorts the list
A.sort()
print(A)
# Out:
# ['20', '9145', 'Gunjan', 'Khopoli', 'Male', 'Statistics', 'T.Y.BSc', 'Tilak Road']

# %% [markdown]
# Tuples
#
# A Tuple is a collection which is ordered and unchangeable
#
# In Python Tuples are wrtten with round brackets.
#
# The key difference between the tuples and lists is that while the tuplesare immutable objects the lists are mutable
#
# this means that tuples cannot be changed while the lists can be modified .
# Tuples are more memory efficient than the lists

# %%
# Create 2 tuples
# A is tuple of Name and basic details
A = ('Gunjan','20','Khopoli')
# B is tuple of college details
B = ('T.Y.BSc','Statistics','9145','Tilak Road')

# %% [markdown]
# Performing various methods

# %%
#1) tuple() : Create tuple with specified elements
t = tuple((1,2,3,4,5,6,7))
print(t)
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %%
#2) len() : gives length of tuple, no. of elements
len(A)
# Out:
# 3

# %%
#3) t1 + t2 : Adds two tuple
C = A + B
print(C)
# Out:
# ('Gunjan', '20', 'Khopoli', 'T.Y.BSc', 'Statistics', '9145', 'Tilak Road')

# %%
#4) del : Delete tuple
del t
print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-babb422940cc> in <module>
#       1 #4) del : Delete tuple
#       2 del t
# ----> 3 print(t)
#
# NameError: name 't' is not defined

# %%
# 5) count() : counts the number of times a specified value occures in a tuple
C1 = ('20',)
C = C + C1
print(C)
C.count('20')
# Out:
# ('Gunjan', '20', 'Khopoli', 'T.Y.BSc', 'Statistics', '9145', 'Tilak Road', '20')
# 2

# %%
# 6) index() : Searches the tuple for a specified value and returns the position where it was found
A.index('20')
# Out:
# 1
