# %%
Name =" Gunjan"
Department = 'Statistics'
github_id = 'gunjan238'
'Sanket'
b = 3
c ="3"
#3 is Number
# "3" is string
# Comment

# %%
# Commen
# To write down the Multiple line Comment
"""dfnsajdknsd
sdfmsdojid
sdnfsdfksa
skdnfjsf"""
'dfnsajdknsd\nsdfmsdojid\nsdnfsdfksa\nskdnfjsf'
# To declare the Variable
#Variable can only be start from A-Z,a-z,_
#We cann't keywords in Python as a Variable
#As Python is Case Sensative laungauge A & a is different variable
# Out:
# 'dfnsajdknsd\nsdfmsdojid\nsdnfsdfksa\nskdnfjsf'

# %%
A_ = 1
a_ =2
a = 3
A = 4

# %%
# Python as A Calculator
x, y = 3.142,  7.98214
print("Addition=",x+y)
print("Subtraction=",x-y)
print("Multiplication=",x*y)  
print("Division=",x/y)
print("Power=",x**y)
print("Modulus=",x%y)
print("Floor division=",x//y)
#Assigning Multiple Values to a Variable
x, y, z,a,b,c,f = "Orange", "Banana", "Cherry",241,"fwdfwe","3235","sdasd"
print(x)
print(y)
print(z)
print(a)
print(b)
print(c)
# Out:
# Addition= 11.12414
# Subtraction= -4.84014
# Multiplication= 25.07988388
# Division= 0.3936287762429624
# Power= 9306.134890344068
# Modulus= 3.142
# Floor division= 0.0
# Orange
# Banana
# Cherry
# 241
# fwdfwe
# 3235
