# %%
a = 22/7
a
# Out:
# 3.142857142857143

# %%
x,y = 10,5
print("Floor division",x//y)   #Gives quotient
# Out:
# Floor division 2

# %%
a = 3.1432
b = 7.98214
print("Addition :",a+b)
print("Subtraction :",a-b)
print("Multiplication :",a*b)
print("Division :",a/b)
print("Power :", a**b)
print("Modulus :",a%b)
print("Floor division :",a//b)
# Out:
# Addition : 11.125340000000001
# Subtraction : -4.83894
# Multiplication : 25.089462448000003
# Division : 0.3937791118672436
# Power : 9334.543034079248
# Modulus : 3.1432
# Floor division : 0.0

# %%
a**1/2
# Out:
# 1.5716

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-8aa58c775b19> in <module>
#       1 import math
# ----> 2 sqrt(a)
#
# TypeError: 'float' object is not callable
